# %% [markdown]
# # Lists: creation, indexing, slicing, modifying.

# %%
fruits = ["Apple", "Banana", "Orange", "Grapes"]

# %%
fruits
# Out:
# ['Apple', 'Banana', 'Orange', 'Grapes']

# %%
age = [20, 54, 57]

# %%
age
# Out:
# [20, 54, 57]

# %%
mixed = [1, "Hello", True, 3.14]

# %%
mixed
# Out:
# [1, 'Hello', True, 3.14]

# %%
mixed[1]
# Out:
# 'Hello'

# %%
fruits[2]
# Out:
# 'Orange'

# %%
fruits[1:4]
# Out:
# ['Banana', 'Orange', 'Grapes']

# %%
fruits.append("Mango")

# %%
fruits
# Out:
# ['Apple', 'Banana', 'Orange', 'Grapes', 'Mango']

# %%
fruits.insert(1, "Mango")

# %%
fruits
# Out:
# ['Apple', 'Mango', 'Banana', 'Orange', 'Grapes', 'Mango']

# %%
fruits.remove("Mango")

# %%
fruits
# Out:
# ['Apple', 'Banana', 'Orange', 'Grapes', 'Mango']

# %%
fruits[3] = "Pineapple"

# %%
fruits
# Out:
# ['Apple', 'Banana', 'Orange', 'Pineapple', 'Mango']

# %% [markdown]
# # Sets: unique elements, operations.

# %%
set_1 = {1,2,3,4,5}
set_2 = {3,4,5,6,7}

# %%
set_1
# Out:
# {1, 2, 3, 4, 5}

# %%
type(set_1)
# Out:
# set

# %%
type(fruits)
# Out:
# list

# %%
union_set = set_1 | set_2

# %%
union_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
common_set = set_1 & set_2

# %%
common_set
# Out:
# {3, 4, 5}

# %%
difference = set_1 - set_2

# %%
difference
# Out:
# {1, 2}

# %%
union_set.add(8)

# %%
union_set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
union_set.remove(1)

# %%
union_set
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %%
sqr_union_set = {x * 2 for x in union_set}

# %%
sqr_union_set
# Out:
# {4, 6, 8, 10, 12, 14, 16}

# %% [markdown]
# # Dictionaries: key-value pairs, methods.

# %%
person = {"name": "Alice", "age": 30, "city": "New York"}

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
person.values()
# Out:
# dict_values(['Alice', 30, 'New York'])

# %%
person.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York')])

# %%
person = {"name": ["Alice", "John"], "age": [30, 25], "city": ["New York", "Dhaka"]}

# %%
person.values()
# Out:
# dict_values([['Alice', 'John'], [30, 25], ['New York', 'Dhaka']])

# %%
person["city"]
# Out:
# ['New York', 'Dhaka']

# %%
person["age"] = [31, 27]

# %%
person
# Out:
# {'name': ['Alice', 'John'], 'age': [31, 27], 'city': ['New York', 'Dhaka']}

# %%
person['email'] = ["alice@example.com", "john@example.com"]

# %%
person
# Out:
# {'name': ['Alice', 'John'],
#  'age': [31, 27],
#  'city': ['New York', 'Dhaka'],
#  'email': ['alice@example.com', 'john@example.com']}
